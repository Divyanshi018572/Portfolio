# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open("temp/Screenshot from 2025-11-30 16-02-27.png")   # path to your image
plt.imshow(img)
plt.axis("off")   # hide axis
plt.show()
